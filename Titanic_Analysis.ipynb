# %% [markdown]
# # Task 1: Dataset Selectionn-
#
# The dataset chosen is the Titanic dataset.
#
# ## Dataset Selection Justificationi- es 	A well-known and often-used dataset in themachine-learningg community is the Titanic dataset. It includes details about the passengers on board the RMS Titanic, such as their racial makeup, ticket type, cabin details, and level of survival (whether they made it or not). Various machine learning tasks, including classification, regression, and data visualization, can benefit from this dataset. It is suitable for binary classification algorithms due to its analysis potential in predicting passenger survival based on the available features. It also enables the exploration of correlations between variables and the extraction of knowledge about the variables that affected the survival rate of passengers during this tragic occurrence It contains information about passengers onboard the RMS Titanic, including their survival status, age, gender, ticket class, and more..use for.]

# %% [markdown]
# # Task 2: Data Exploration with Python
#
# #a. # Exploratory Data Analysis (EDA) - Titanic Datast
#
# In this sectiorm exploratory data analysis (Ewill be performed DA) on the Titanic dataset. EDA involves summarizing and visualizing the dataset to gain insights into its structure, distributions, and relationships among variables.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the Titanic dataset
tit_df = pd.read_csv("C:/Users/rizwi/Desktop/bdsa/ProgBigData/titanic.csv")
print(tit_df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ![image.png](attachment:b4e06db4-b878-4261-b6c8-5e592b42447c.png)

# %% [markdown]
# ## b. Generate summary statistics, identify data types, and visualize the data distribution to gain insights into the dataset.
# **Summary Statistics**
#
# Let's start by displaying the summary statistics of the Titanic dataset to get an overview of its numerical features, such as age, fare, and more.

# %%
# Summary statistics
print(tit_df.describe())
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ![image.png](attachment:b5cc187f-cb31-4976-ab01-ef7d9b66af6c.png)

# %% [markdown]
# **Data Types**
#
# Next, we will examine the data types of each column in the dataset to understand how the data is stored and identify categorical and numerical features.

# %%
# Data types
print(tit_df.dtypes)
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# ![image.png](attachment:50b36a78-0987-475a-a91a-aea78e2cbeaf.png)

# %% [markdown]
# ### Data Distribution Visualization
#
# To visualize the data distribution, we will create various plots to explore the relationships between different variables in the dataset.
#
# ### Plot 1: Survival Distribution
#
# The first plot shows the distribution of survival status among passengers. We can observe the proportion of survivors and non-survivors.
#
# ### Plot 2: Survival by Passenger Class
#
# The second plot illustrates the survival rate based on passenger class. This plot helps us understand if there is any correlation between ticket class and survival.
#
# ### Plot 3: Age Distribution
#
# The third plot represents the distribution of passengers' ages. This histogram provides insights into the age distribution of the passengers onboard.
#
# ### Plot 4: Survival by Gender
#
# The fourth plot displays the survival rate based on gender. It allows us to analyze the impact of gender on passenger survival.

# %%
# Data distribution visualization
sns.set(style="whitegrid")

# Plot 1: Survival Distribution
plt.figure(figsize=(10, 6))
sns.countplot(x='Survived', data=tit_df)
plt.title('Survival Distribution')
plt.show()

# %% [markdown]
# ![image.png](attachment:aa9e8e2e-03fb-4535-8a18-4bb7abc2f4c7.png)

# %%
# Plot 2: Survival by Passenger Class
plt.figure(figsize=(10, 6))
sns.countplot(x='Pclass', hue='Survived', data=tit_df)
plt.title('Survival by Passenger Class')
plt.show()

# %% [markdown]
# ![image.png](attachment:7b4ca595-889d-4337-ac90-76b41e4830c4.png)

# %%
# Plot 3: Age Distribution
plt.figure(figsize=(10, 6))
sns.histplot(data=tit_df, x='Age', bins=20)
plt.title('Age Distribution')
plt.show()

# %% [markdown]
# ![image.png](attachment:98103269-bdcb-479c-9456-1f2bacba7a02.png)

# %%
# Plot 4: Survival by Gender
plt.figure(figsize=(10, 6))
sns.countplot(x='Sex', hue='Survived', data=tit_df)
plt.title('Survival by Gender')
plt.show()

# %% [markdown]
# ![image.png](attachment:44939306-dedf-4c06-838e-20239b5bb7fa.png)

# %% [markdown]
# # Task 3: Data Preprocessing with Python
# a.
#
# ## Data Preprocessing - Titanic Dataset
#
# In this section, we will preprocess the Titanic dataset to prepare it for machine learning models. The preprocessing steps include handling missing values, handling outliers, and performing feature engineering when necessab.ry.
#
# ### Step 1: Handle Missing Values
#
# We will start by handling missing values in the dataset. We fill missing age values with the mean age and missing embarked values with the most frequeng and further use.

# %%
# Step 1: Handle Missing Values
tit_df['Age'].fillna(tit_df['Age'].mean(), inplace=True)  # Filling missing Age values with the mean
tit_df['Embarked'].fillna(tit_df['Embarked'].mode()[0], inplace=True)  # Filling missing Embarked values with the mode
print(tit_df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %% [markdown]
# ![image.png](attachment:81fe57ad-830e-42e2-b179-ee6380b9898e.png)

# %% [markdown]
# ### Step 2: Handle Outliers using Z-score Thresholding
#
# Next, the outliers are detected and handled in numerical features using the Z-score method. The model performance can be badly affected by the outliers, so it's essential to handle them appropriately.

# %%
# Step 2: Handle Outliers using Z-score thresholding
from scipy import stats

# Define Z-score threshold for outlier detection
z_threshold = 3

# Identify outliers in numerical features
outliers = (np.abs(stats.zscore(tit_df[['Age', 'Fare']])) > z_threshold).any(axis=1)

# Remove rows with outliers
tit_df = tit_df[~outliers]
print("Outliers Handled")
print(tit_df)
# Out:
# Outliers Handled
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %% [markdown]
# ![image.png](attachment:abee9ecb-65eb-4b9c-84e5-1aac80645227.png)

# %% [markdown]
# ### Step 3: Feature Engineering (if necessary)
#
# Feature engineering is the process of adding new features or changing existing ones to enhance the performance of models. In this example, we'll combine the features "SibSp" (number of siblings/spouses aboard) and "Parch" (number of parents/children aboard) to create a new feature called "FamilySize." This new function can measure the impact of family size on survival.
#
# ### Data is Now Ready for Machine Learning Models
#
# After preprocessing the data, it is now ready for training machine learning models. We will split the data into features (X) and the target (y) for model training and further use.

# %%
# Step 3: Feature Engineering (if necessary)
# [Explanation for Feature Engineering, if applicable]
# For this example, let's create a new feature 'FamilySize' by combining 'SibSp' and 'Parch'.
tit_df['FamilySize'] = tit_df['SibSp'] + tit_df['Parch']
print("Step 3: Feature Engineering Completed")
print(tit_df.head())

# split the data into features (X) and target (y) for model training and further use.
X = tit_df.drop('Survived', axis=1)
y = tit_df['Survived']
print("X (Features):")
print(X.head())
print("y (Target):")
print(y.head())
# Out:
# Step 3: Feature Engineering Completed
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  FamilySize
# 0      0         A/5 21171   7.2500   NaN        S           1
# 1      0          PC 17599  71.2833   C85        C           1
# 2      0  STON/O2. 3101282   7.9250   NaN        S           0
# ...

# %% [markdown]
# ![image.png](attachment:4d430ede-8924-40fa-b737-9fbc56fbcf77.png)
# ![image.png](attachment:1d0884b0-8994-4940-b81c-a3f38fce5498.png)

# %% [markdown]
# ## Task 4: Implement Machine Learning Models with Python
# ### a. The two models used to implement machine learning are SVM and Random Forest Classifier.
# **Support Vector Machine (SVM) Model**
# - The survival of Titanic passengers will be predicted using a Support Vector Machine (SVM) model in this section.
# -  The SVM model is a potent classification technique that seeks to identify the ideal hyperplane that best distinguishes between the two classes, in this case, whether or not a passenger survived.
# - The SVM model seeks to identify the decision border with the greatest margin of separation between the two classes. This algorithm is flexible and works with both linear and non-linear data.e Titanic dataset.

# %%
from sklearn.impute import SimpleImputer  # Import the imputer
X = tit_df.drop('Survived', axis=1)
y = tit_df['Survived']

# Drop non-numeric columns from the feature set
X_numeric = X.select_dtypes(include='number')

# Use SimpleImputer to handle missing values (replace NaN with mean)
imputer = SimpleImputer(strategy='mean')
X_numeric_imputed = imputer.fit_transform(X_numeric)

# Split the data into training and testing sets (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(X_numeric_imputed, y, test_size=0.2, random_state=42)

# Standardize the features using StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Initialize the SVM model
svm_model = SVC()

# Train the model
svm_model.fit(X_train_scaled, y_train)

# Make predictions on the test set
y_pred_svm = svm_model.predict(X_test_scaled)

# Evaluate the performance of the model
accuracy_svm = accuracy_score(y_test, y_pred_svm)
precision_svm = precision_score(y_test, y_pred_svm)
recall_svm = recall_score(y_test, y_pred_svm)
f1_svm = f1_score(y_test, y_pred_svm)
confusion_matrix_svm = confusion_matrix(y_test, y_pred_svm)
classification_report_svm = classification_report(y_test, y_pred_svm)

# Display the results
print("Support Vector Machine (SVM) Results:")
print("Accuracy:", accuracy_svm)
print("Precision:", precision_svm)
print("Recall:", recall_svm)
print("F1 Score:", f1_svm)
print("Confusion Matrix:")
print(confusion_matrix_svm)
print("Classification Report:")
print(classification_report_svm)
# Out:
# Support Vector Machine (SVM) Results:
# Accuracy: 0.7541899441340782
# Precision: 0.8571428571428571
# Recall: 0.4864864864864865
# F1 Score: 0.6206896551724138
# Confusion Matrix:
# [[99  6]
#  [38 36]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.72      0.94      0.82       105
#            1       0.86      0.49      0.62        74
#
#     accuracy                           0.75       179
#    macro avg       0.79      0.71      0.72       179
# weighted avg       0.78      0.75      0.74       179

# %% [markdown]
# ![image.png](attachment:17c73041-df66-401c-9427-625824b2495a.png)

# %% [markdown]
# **Random Forest Classifier**
# - In this section, we'll look at how the Random Forest Classifier can be used to forecast whether or not Titanic passengers would survive. An ensemble learning technique called the Random Forest algorithm mixes various decision trees to produce predictions.
# - It is renowned for its dependability and capacity to manage intricate data interactions.
# - Powerful classification algorithms like the Random Forest Classifier are frequently employed for a variety of purposes, including machine learning.
# # Let's go forward with putting the Random Forest Classifier model into practice and gauging how well it performs on the Titanic dataset.

# %%
X = tit_df.drop('Survived', axis=1)
y = tit_df['Survived']
# Drop non-numeric columns from the feature set
X_numeric = X.select_dtypes(include='number')

# Use SimpleImputer to handle missing values (replace NaN with mean)
imputer = SimpleImputer(strategy='mean')
X_numeric_imputed = imputer.fit_transform(X_numeric)

# Split the data into training and testing sets (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(X_numeric_imputed, y, test_size=0.2, random_state=42)

# Initialize the Random Forest Classifier
rf_model = RandomForestClassifier(random_state=42)

# Train the model
rf_model.fit(X_train, y_train)

# Make predictions on the test set
y_pred_rf = rf_model.predict(X_test)

# Evaluate the performance of the model
accuracy_rf = accuracy_score(y_test, y_pred_rf)
precision_rf = precision_score(y_test, y_pred_rf)
recall_rf = recall_score(y_test, y_pred_rf)
f1_rf = f1_score(y_test, y_pred_rf)
confusion_matrix_rf = confusion_matrix(y_test, y_pred_rf)
classification_report_rf = classification_report(y_test, y_pred_rf)

# Display the results
print("Random Forest Classifier Results:")
print("Accuracy:", accuracy_rf)
print("Precision:", precision_rf)
print("Recall:", recall_rf)
print("F1 Score:", f1_rf)
print("Confusion Matrix:")
print(confusion_matrix_rf)
print("Classification Report:")
print(classification_report_rf)
# Out:
# Random Forest Classifier Results:
# Accuracy: 0.7206703910614525
# Precision: 0.6818181818181818
# Recall: 0.6081081081081081
# F1 Score: 0.6428571428571428
# Confusion Matrix:
# [[84 21]
#  [29 45]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.74      0.80      0.77       105
#            1       0.68      0.61      0.64        74
#
#     accuracy                           0.72       179
#    macro avg       0.71      0.70      0.71       179
# weighted avg       0.72      0.72      0.72       179

# %% [markdown]
# ![image.png](attachment:c83675e5-e7b1-49c6-93b1-ae67ec6661e7.png)

# %% [markdown]
# ### b. Based on the performance metrics obtained from both Support Vector Machine (SVM) model and the Random Forest Classifier, we can compare the two models to determine which one is more suitable for the dataset.
# - Accuracy: In comparison to the Random Forest Classifier, which had an accuracy of 0.72, the SVM model had a marginally higher accuracy of 0.75. The difference is negligible, though.
# -
# Precision: The SVM model performs better at reliably detecting true positives among its predictions, as evidenced by its higher precision of 0.86. The precision of the Random Forest Classifier is 0.6
# -
#
# Recall: With a greater recall of 0.61, the Random Forest Classifier is better able to distinguish between true positives and samples that are actually positiThe recallcall for the SVM model is 0
# - 9.
#
# F1 Score: The harmonic mean of recall and precision is the F1 score. The Random Forest Classifier gets an F1 score of 0.64 compared to the SVM model's 0.62. The Random Forest model performs slightly better in this m
# ## The Random Forest Classifier appears to reach a better balance when weighing the trade-off between precision and recall, which means it can find a greater percentage of genuine positive cases (survived passengers). The Random Forest model performs marginally better, as evidenced by the F1 score, which takes precision and recall into account.
#
# ### In conclusion, the Random Forest Classifier is the better model for this dataset based on the stated metrics. The choice of a model, however, may be influenced by other elements, such as interpretability, computational effectiveness, and the particular specifications of the issue you are attempting to address.
# etric.

# %% [markdown]
# **Task 5: Visualization with Python**
# - In this task, we'll use Python packages like Matplotlib and Seaborn to produce insightful visualizations for the Titanic dataset. Visualizations are crucial for deriving insights from data and for comprehending patterns and connections between various features.
# .###
#
# Visualization 1: Scatter Plot - Age vs. FaThe scatter plot illustrates the correlation between age and fare, with data points colored according to the degree of survival. The passengers' fares are shown on the y-axis, and their ages are shown on the x-axis. Each data point's color reflects whether or not the passenger survived. We may investigate any potential relationships between age, fare, and survival status using this image.
# atus.

# %%
# Visualization 1: Scatter Plot - Age vs. Fare
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Age', y='Fare', data=tit_df, hue='Survived', palette='coolwarm')
plt.title('Scatter Plot - Age vs. Fare')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.show()
# Out:
# C:\Users\rizwi\AppData\Local\Temp\ipykernel_32368\2298063803.py:18: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Pclass', y='Survived', data=tit_df, ci=None)

# %% [markdown]
# ![image.png](attachment:8b6af7b5-a350-4fa8-8919-17d0b69632f6.png)

# %% [markdown]
# ### Visualization 2: Heatmap - Correlation Matrix
# The correlation matrix between the dataset's numerical features is depicted by the heatmap. The correlation coefficient between the two features is shown in each heatmap cell. Values that are near 0 show no correlation at all, whereas values that are positive or negative indicate either a positive or negative correlation. This graphic exposes potential multicollinearity problems and aids in the identification of linkages between features.s.

# %%
# Visualization 2: Heatmap - Correlation Matrix
plt.figure(figsize=(10, 8))
correlation_matrix = tit_df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Heatmap - Correlation Matrix')
plt.show()

# %% [markdown]
# ![image.png](attachment:9788273d-2b34-48cf-94bd-a5d892179241.png)

# %% [markdown]
# ### Visualization 3: Bar Chart - Survival by Pclass
# The survival probability for various Passenger Classes (Pclass) is compared in the bar chart. The survival rate for each bar corresponds to a certain passenger class. We can determine whether the passenger class has a substantial effect on survival chances by looking at the variations in survival rates.l.

# %%
# Visualization 3: Bar Chart - Survival by Pclass
plt.figure(figsize=(8, 6))
sns.barplot(x='Pclass', y='Survived', data=tit_df, ci=None)
plt.title('Bar Chart - Survival by Pclass')
plt.xlabel('Passenger Class')
plt.ylabel('Survival Probability')
plt.show()

# %% [markdown]
# ![image.png](attachment:06f28c12-0676-4b88-bc60-d246156cf052.png)

# %% [markdown]
# ### Visualization 4: Box Plot - Age by Pclass
# The distribution of ages for each Passenger Class (Pclass) is shown on the box plot. The horizontal line inside each box, which represents the interquartile range (IQR) of age for a particular class, indicates the median value. This image enables us to spot any differences in the age distribution among various passenger classes.

# %%
# Visualization 4: Box Plot - Age by Pclass
plt.figure(figsize=(8, 6))
sns.boxplot(x='Pclass', y='Age', data=tit_df, palette='Set2')
plt.title('Box Plot - Age by Pclass')
plt.xlabel('Passenger Class')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# ![image.png](attachment:58f9b013-fc10-4d54-b56e-0f8294345766.png)

# %%
git add Titanic_Analysis.ipynb
